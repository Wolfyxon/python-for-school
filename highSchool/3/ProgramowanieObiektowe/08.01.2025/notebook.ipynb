# %%
import pandas as pd

data = {
    "name": ["Wolfyxon", "Friderick von Fazbear", "The", "Gordon Freeman"],
    "age": [16, 8, 20, 41],
    "gender": ["male", "horhor", "the", "female"]
}

frame = pd.DataFrame(data)
frame["age"].hist()

frame
# Out:
#                     name  age  gender
# 0               Wolfyxon   16    male
# 1  Friderick von Fazbear    8  horhor
# 2                    The   20     the
# 3         Gordon Freeman   41  female

# %%
import pandas as pd

frame = pd.read_csv("abalone.csv")
frame.plot()
# Out:
# <Axes: >
